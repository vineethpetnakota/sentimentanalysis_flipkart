# %%
import numpy as np
import pandas as pd

df=pd.read_csv("/Users/vineethpetnakota/desktop/flipkart_product_final_ppt.csv",encoding="unicode_escape")
df.head()
# Out:
#                                          ProductName Price(Rs)  Rating  \
# 0  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 1  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 2  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 3  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 4  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
#
#             Review                                            Summary
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189874 entries, 0 to 189873
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ProductName  189870 non-null  object
#  1   Price(Rs)    189869 non-null  object
#  2   Rating       189869 non-null  float64
#  3   Review       189866 non-null  object
#  4   Summary      189856 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 7.2+ MB

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns #visualize
from textblob import TextBlob
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
import re
import wordcloud
from PIL import Image

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189874 entries, 0 to 189873
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ProductName  189870 non-null  object
#  1   Price(Rs)    189869 non-null  object
#  2   Rating       189869 non-null  float64
#  3   Review       189866 non-null  object
#  4   Summary      189856 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 7.2+ MB

# %%
def extract_price(p):
    expression = r'\d+'
    match = re.findall(expression,p)
    return ''.join(match)

df['Price(Rs)'] = df['Price(Rs)'].astype(str)
df['ExtractedPrice'] = df['Price(Rs)'].apply(extract_price)
df.head()
# Out:
#                                          ProductName Price(Rs)  Rating  \
# 0  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 1  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 2  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 3  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 4  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
#
#             Review                                            Summary  \
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product
#
#   ExtractedPrice
# 0           3999
# 1           3999
# 2           3999
# 3           3999
# 4           3999

# %%
df['Rating'].unique()
# Out:
# array([ 5.,  3.,  1.,  4.,  2., nan])

# %%
df['Summary'] = df['Summary'].astype(str)

# %%
subjectivity_list = []
polarity_list = []
for review in df['Summary']:
    tb = TextBlob(review)
    subjectivity_list.append(tb.sentiment.subjectivity)
    polarity_list.append(tb.sentiment.polarity)
    
#Add the result to the DataFrame
df['Subjectivity'] = subjectivity_list
df['Polarity'] = polarity_list
df.head()
# Out:
#                                          ProductName Price(Rs)  Rating  \
# 0  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 1  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 2  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 3  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 4  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
#
#             Review                                            Summary  \
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product
#
#    Subjectivity  Polarity
# 0      0.812500  0.725000
# 1      0.566667  0.666667
# 2      0.633333  0.433333
# 3      0.933333 -0.455000
# 4      0.500000  0.500000

# %%
def sentiment_analysis(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'
df['Sentiment'] = df['Polarity'].apply(sentiment_analysis)
df.head()
# Out:
#                                          ProductName Price(Rs)  Rating  \
# 0  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 1  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 2  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 3  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 4  Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
#
#             Review                                            Summary  \
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product
#
#    Subjectivity  Polarity Sentiment
# 0      0.812500  0.725000  Positive
# 1      0.566667  0.666667  Positive
# 2      0.633333  0.433333  Positive
# 3      0.933333 -0.455000  Negative
# 4      0.500000  0.500000  Positive

# %%
df.head(20)
# Out:
#                                           ProductName Price(Rs)  Rating  \
# 0   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 1   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 2   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 3   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 4   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 5   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 6   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     5.0
# 7   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     3.0
# 8   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     1.0
# 9   Candes 12 L Room/Personal Air Cooler(White, Bl...     3,999     4.0
# 10  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 11  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 12  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 13  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 14  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 15  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 16  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 17  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 18  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
# 19  Candes 60 L Room/Personal Air Cooler(White, Bl...     8,999     5.0
#
#                    Review                                            Summary  \
# 0                  Super!  Great cooler.. excellent air flow and for this...
# 1                 Awesome             Best budget 2 fit cooler. Nice cooling
# 2                    Fair  The quality is good but the power of air is de...
# 3         Useless product                 Very bad product it's a only a fan
# 4                    Fair                                      Ok ok product
# 5                 Awesome  The cooler is really fantastic and provides go...
# 6      Highly recommended                                  Very good product
# 7                    Nice                                          Very nice
# 8          Unsatisfactory                                    Very bad cooler
# 9         Worth the money                                          Very good
# 10          Great product  Beautiful product good material and perfectly ...
# 11  Mind-blowing purchase                                            Awesome
# 12     Highly recommended                                               Good
# 13              Brilliant                        Wonderful product, Must buy
# 14         Classy product        Nice air cooler, smart cool breeze producer
# 15              Must buy!                                               Awsm
# 16              Fabulous!                                  Nice product ???
# 17      Worth every penny                                     Great cooler..
# 18                 Super!                                       Nice product
# 19          Great product                                          Good ???
#
#    ExtractedPrice  Subjectivity  Polarity Sentiment
# 0            3999      0.812500  0.725000  Positive
# 1            3999      0.566667  0.666667  Positive
# 2            3999      0.633333  0.433333  Positive
# 3            3999      0.933333 -0.455000  Negative
# 4            3999      0.500000  0.500000  Positive
# 5            3999      0.680000  0.420000  Positive
# 6            3999      0.780000  0.910000  Positive
# 7            3999      1.000000  0.780000  Positive
# 8            3999      0.866667 -0.910000  Negative
# 9            3999      0.780000  0.910000  Positive
# 10           8999      0.866667  0.850000  Positive
# 11           8999      1.000000  1.000000  Positive
# 12           8999      0.600000  0.700000  Positive
# 13           8999      1.000000  1.000000  Positive
# 14           8999      0.764286  0.388095  Positive
# 15           8999      0.000000  0.000000   Neutral
# 16           8999      1.000000  0.600000  Positive
# 17           8999      0.750000  0.800000  Positive
# 18           8999      1.000000  0.600000  Positive
# 19           8999      0.600000  0.700000  Positive

# %%
#Visualization of the sentiment analysis

plt.figure(figsize=(8,6))
plt.scatter(df.Polarity[10], df.Subjectivity[10], color = '#1874CD')
plt.axhline(y = np.mean(df.Subjectivity), color = '#7FFF00')
plt.axvline(x = np.mean(df.Polarity), color = '#FF4040')
plt.xlabel("Polarity")
plt.xlim((-1, 1))
plt.ylabel("Subjectivity")
plt.ylim((0, 1))
plt.show()

# %%
sns.countplot(x=df.head(20)["Sentiment"], color = '#FF7256')
# Out:
# <AxesSubplot:xlabel='Sentiment', ylabel='count'>

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

ignored_words = set(stopwords.words("english"))
ignored_words.add("bad")
ignored_words.add("good")
ignored_words.add("flipkart")
ignored_words.add("also")
ignored_words.add("like")
ignored_words.add("item")
ignored_words.add("one")
ignored_words.add("much")
ignored_words.add("even")
ignored_words.add("product")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vineethpetnakota/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vineethpetnakota/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
review_list = []
tokens = []
for r in df[df["Sentiment"] == "Negative"]["Summary"]:
    r = r.lower() #lowercase of the review
    r = re.sub("http?:\/\/\S+"," ",r) #Remove hyperlinks if any
    r = re.sub(r"\s+[a-zA-Z]\s+", " ", r) #Remove single characters
    for token in word_tokenize(r):
        if token.isalpha() and token not in ignored_words: #Remove stop words
            tokens.append(token)
s = " ".join(tokens)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud


text_column = df['Sentiment'] 

# Concatenate the text from the selected column
text = ' '.join(text_column)

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score


# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['Subjectivity'], df['Polarity'], test_size=0.2, random_state=42)

# Create a TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Convert text data to numerical features
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Build the model (e.g., Logistic Regression)
model = LogisticRegression()

# Train the model
model.fit(X_train_vec, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_vec)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lq/cw1247s92vv0ksm42yy0h9v00000gn/T/ipykernel_1242/2555114505.py in <module>
#      13
#      14 # Convert text data to numerical features
# ---> 15 X_train_vec = vectorizer.fit_transform(X_train)
#      16 X_test_vec = vectorizer.transform(X_test)
#      17
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2075         """
#    2076         self._check_params()
# -> 2077         X = super().fit_transform(raw_documents)
#    2078         self._tfidf.fit(X)
#    2079         # X is already a transformed view of raw_documents so
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1199         for doc in raw_documents:
#    1200             feature_counter = {}
# -> 1201             for feature in analyze(doc):
#    1202                 try:
#    1203                     feature_idx = vocabulary[feature]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     111     else:
#     112         if preprocessor is not None:
# --> 113             doc = preprocessor(doc)
#     114         if tokenizer is not None:
#     115             doc = tokenizer(doc)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      69     """
#      70     if lower:
# ---> 71         doc = doc.lower()
#      72     if accent_function is not None:
#      73         doc = accent_function(doc)
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lq/cw1247s92vv0ksm42yy0h9v00000gn/T/ipykernel_12556/3771845804.py in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
